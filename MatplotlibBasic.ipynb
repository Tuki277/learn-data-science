# %%
# introduction

# %%
# !pip3 install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.8.3-cp311-cp311-macosx_11_0_arm64.whl (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 5.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.2.0-cp311-cp311-macosx_11_0_arm64.whl (243 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 5.5 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.49.0-cp311-cp311-macosx_10_9_universal2.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 8.7 MB/s eta 0:00:00 MB/s eta 0:00:010:01
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.5-cp311-cp311-macosx_11_0_arm64.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1.21 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/tuki/Library/Python/3.11/lib/python/site-packages (from matplotlib) (23.2)
# Collecting pillow>=8
#   Downloading pillow-10.2.0-cp311-cp311-macosx_11_0_arm64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 8.1 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tuki/Library/Python/3.11/lib/python/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.49.0 kiwisolver-1.4.5 matplotlib-3.8.3 pillow-10.2.0 pyparsing-3.1.1
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
x = [1, 2, 3, 4]
y = [10, 8, 6, 9]
plt.plot(x, y)

# %%
# Pylot API vs Object Oriented API

# %%
x = np.linspace(0, 10, 1000)

# %%
plt.style.use('seaborn-v0_8-whitegrid')
plt.plot(x, np.sin(x), label="sin(x)")
plt.plot(x, np.cos(x), color="red", label="cos(x)")
plt.title("sin(x) and cos(x)")
plt.xlabel("Bien X")
plt.ylabel("Sin (X)")
plt.legend()
# plt.xlim([0, 4])
# plt.ylim([-0.75, 0.75])
plt.axis("equal")
# Out:
# (-0.5, 10.5, -1.0999987378908789, 1.0999999398995657)

# %%
## object orient api

# %%
# prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]


# setup plot
fig, ax = plt.subplots(figsize=(5,5))

# plot the data
ax.plot(x, y)

ax.set(title="A simple plot", xlabel="x label", ylabel="y label")
# Out:
# [Text(0.5, 1.0, 'A simple plot'),
#  Text(0.5, 0, 'x label'),
#  Text(0, 0.5, 'y label')]

# %%
# 2 most common type of Matplotlib plots
# line
# scatter
# bar
# hist
# subplots()

# %%
#line

# %%
#create an array

# %%
x = np.linspace(0, 10, 100)
x[:5]
# Out:
# array([0.       , 0.1010101, 0.2020202, 0.3030303, 0.4040404])

# %%
fig, ax = plt .subplots()
ax.plot(x, x**3)

# %%
# scatter

# %%
#pyplot API

plt.scatter(x, np.exp(x)) # y = e^x

# %%
rng = np.random.RandomState(0)

x = rng.randn(100)
y = rng.randn(100)

fig, ax = plt.subplots()
# ax.scatter(x, y)

colors = rng.rand(100)
sizes = 1000*rng.rand(100)

img1 = ax.scatter(x,y, s=sizes, c=colors, cmap='viridis', alpha=0.3)
fig.colorbar(img1)

# %%
# vertical bar horizontal bar

# %%
# prepare data from python dictionary
soft_drink_prices = {"coke": 10, "pessi": 12, "Sprite": 8}

fig, ax = plt.subplots()
ax.bar(soft_drink_prices.keys(), soft_drink_prices.values())
ax.set(title="Bach hoa xanh", ylabel="Price $")
# Out:
# [Text(0.5, 1.0, 'Bach hoa xanh'), Text(0, 0.5, 'Price $')]

# %%
fig, ax = plt.subplots()
ax.barh(list(soft_drink_prices.keys()), list(soft_drink_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
# histogram

# %%
student_height = np.random.normal(170, 10, 250)

# %%
student_height
# Out:
#        170.50375488, 178.76191766, 177.24864903, 182.09450404,
#        162.30087002, 177.94646405, 156.36889349, 164.66596325,
#        173.35268425, 169.98588293, 173.21291147, 156.35228542,
#        166.23905473, 160.09352967, 162.94694247, 180.39106883,
#        175.44044703, 175.05925984, 158.47852483, 165.60132288,
#        168.35439193, 168.2851021 , 163.77866777, 172.96189798,
#        178.24819483, 170.52382472, 171.90197263, 157.06364018,
#        175.89676171, 167.83606917, 176.42123893, 166.37914081,
#        167.71337057, 159.18812468, 184.97043292, 164.95907671,
#        181.14865531, 167.24303773, 158.50084511, 175.39099991,
#        156.23624596, 160.1702422 , 172.65530354, 164.60579617,
#        180.61569872, 163.97487425, 167.38862731, 167.25290028,
#        186.51280429, 172.560475  , 161.67717221, 171.64434027,
#        180.36099132, 167.9891959 , 165.98421754, 177.43897208,
#        156.58164734, 164.79169837, 163.8399082 , 181.3473732 ,
#        179.49922348, 163.20121466, 164.73681059, 164.20159899,
#        169.09588634, 163.54149161])

# %%
#pyplot API
plt.hist(student_height, bins=30)
# Out:
# (array([ 1.,  1.,  1.,  0.,  1.,  0.,  2.,  5., 11., 10., 17., 15., 19.,
#         19., 18., 21., 20., 19., 18., 14., 14.,  6.,  8.,  5.,  3.,  0.,
#          0.,  0.,  0.,  2.]),
#  array([140.33932339, 142.29014519, 144.24096699, 146.19178879,
#         148.14261058, 150.09343238, 152.04425418, 153.99507598,
#         155.94589778, 157.89671958, 159.84754138, 161.79836317,
#         163.74918497, 165.70000677, 167.65082857, 169.60165037,
#         171.55247217, 173.50329397, 175.45411576, 177.40493756,
#         179.35575936, 181.30658116, 183.25740296, 185.20822476,
#         187.15904656, 189.10986835, 191.06069015, 193.01151195,
#         194.96233375, 196.91315555, 198.86397735]),
#  <BarContainer object of 30 artists>)

# %%
#subplots

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

#plot data to each axis
ax1.plot(x, x/2)
ax1.plot(x, x*2)

ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(soft_drink_prices.keys(), soft_drink_prices.values())
ax4.hist(student_height, bins=30)
# Out:
# (array([ 1.,  1.,  1.,  0.,  1.,  0.,  2.,  5., 11., 10., 17., 15., 19.,
#         19., 18., 21., 20., 19., 18., 14., 14.,  6.,  8.,  5.,  3.,  0.,
#          0.,  0.,  0.,  2.]),
#  array([140.33932339, 142.29014519, 144.24096699, 146.19178879,
#         148.14261058, 150.09343238, 152.04425418, 153.99507598,
#         155.94589778, 157.89671958, 159.84754138, 161.79836317,
#         163.74918497, 165.70000677, 167.65082857, 169.60165037,
#         171.55247217, 173.50329397, 175.45411576, 177.40493756,
#         179.35575936, 181.30658116, 183.25740296, 185.20822476,
#         187.15904656, 189.10986835, 191.06069015, 193.01151195,
#         194.96233375, 196.91315555, 198.86397735]),
#  <BarContainer object of 30 artists>)
